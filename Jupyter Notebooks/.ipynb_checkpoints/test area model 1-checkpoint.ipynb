# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
train_labels = None
train_images = None
test_labels = None
test_images = None
class_names = None
history = None

# %%
def processDataset():
    global train_labels
    global train_images
    global test_labels
    global test_images
    global class_names
    
    (train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()
    
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
    
    train_images = train_images / 255.0
    test_images = test_images / 255.0
    
print(train_labels)
processDataset()
print(train_labels)
# Out:
# None
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]

# %%
def showDataset():
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(train_images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[train_labels[i][0]])
    plt.show()
    
showDataset()

# %%
def trainModel(model, epochCount):
    global history
    
    model.summary()
    
    #model.build()
    
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    
    history = model.fit(train_images, train_labels, epochs=epochCount, 
                    validation_data=(test_images, test_labels))
    
    showAccuracy()
    showLoss()
    evaluateModel(model)
    showPredictions(model)

# %%
def showAccuracy():
    plt.figure(1)
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')

# %%
def showLoss():
    plt.figure(2)
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.ylim([0, 2])
    plt.legend(loc='lower right')

# %%
def evaluateModel(model):
    test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
    print('Acc: ' + test_acc)
    print('Loss:' + test_loss)

# %%
def showPredictions(model):
    probability_model = keras.Sequential([model, keras.layers.Softmax()])
    predictions = probability_model.predict(test_images)
    
    num_rows = 5
    num_cols = 3
    num_images = num_rows*num_cols
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    for i in range(num_images):
      plt.subplot(num_rows, 2*num_cols, 2*i+1)
      plot_image(i, predictions[i], test_labels, test_images)
      plt.subplot(num_rows, 2*num_cols, 2*i+2)
      plot_value_array(i, predictions[i], test_labels)
    plt.tight_layout()
    plt.show()


    
    
    
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# ### Model 1, relu

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='relu', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])

trainModel(model, 20)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_60 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
#  8960/50000 [====>.........................] - ETA: 14s - loss: 1.8868 - accuracy: 0.2929
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-b1505feb9df1> in <module>
#      14 ])
#      15
# ---> 16 trainModel(model, 20)
#
# <ipython-input-35-aa72947e8fef> in trainModel(model, epochCount)
#      11
#      12     history = model.fit(train_images, train_labels, epochs=epochCount,
# ---> 13                     validation_data=(test_images, test_labels))
#      14
#      15     showAccuracy()
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 1, tanh

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='tanh', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='tanh'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='tanh'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='tanh'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])

trainModel(model, 50)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_72 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 16s 326us/sample - loss: 1.4697 - accuracy: 0.4796 - val_loss: 1.2763 - val_accuracy: 0.5568
# Epoch 2/50
# 50000/50000 [==============================] - 15s 304us/sample - loss: 1.2139 - accuracy: 0.5780 - val_loss: 1.1196 - val_accuracy: 0.6195
# Epoch 3/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 1.1166 - accuracy: 0.6162 - val_loss: 1.0908 - val_accuracy: 0.6299
# Epoch 4/50
# 50000/50000 [==============================] - 15s 302us/sample - loss: 1.0410 - accuracy: 0.6436 - val_loss: 0.9736 - val_accuracy: 0.6743
# Epoch 5/50
# 50000/50000 [==============================] - 15s 306us/sample - loss: 1.0052 - accuracy: 0.6555 - val_loss: 0.9187 - val_accuracy: 0.6891
# Epoch 6/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 0.9735 - accuracy: 0.6664 - val_loss: 0.9464 - val_accuracy: 0.6794
# Epoch 7/50
# 50000/50000 [==============================] - 15s 304us/sample - loss: 0.9647 - accuracy: 0.6700 - val_loss: 0.9110 - val_accuracy: 0.6888
# Epoch 8/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 0.9528 - accuracy: 0.6740 - val_loss: 0.9192 - val_accuracy: 0.6869
# Epoch 9/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 0.9431 - accuracy: 0.6766 - val_loss: 0.9231 - val_accuracy: 0.6856
# Epoch 10/50
# 50000/50000 [==============================] - 15s 304us/sample - loss: 0.9466 - accuracy: 0.6753 - val_loss: 0.9154 - val_accuracy: 0.6874
# Epoch 11/50
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.9311 - accuracy: 0.6814 - val_loss: 0.9066 - val_accuracy: 0.6957
# Epoch 12/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 0.9332 - accuracy: 0.6803 - val_loss: 0.8732 - val_accuracy: 0.7043
# Epoch 13/50
# 50000/50000 [==============================] - 15s 299us/sample - loss: 0.9281 - accuracy: 0.6835 - val_loss: 0.9102 - val_accuracy: 0.6929
# Epoch 14/50
# 50000/50000 [==============================] - 15s 300us/sample - loss: 0.9250 - accuracy: 0.6839 - val_loss: 0.9340 - val_accuracy: 0.6875
# Epoch 15/50
# 50000/50000 [==============================] - 16s 318us/sample - loss: 0.9158 - accuracy: 0.6874 - val_loss: 0.8709 - val_accuracy: 0.7082
# Epoch 16/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.9256 - accuracy: 0.6809 - val_loss: 0.9093 - val_accuracy: 0.6941
# Epoch 17/50
# 50000/50000 [==============================] - 15s 307us/sample - loss: 0.9178 - accuracy: 0.6854 - val_loss: 0.8875 - val_accuracy: 0.7027
# Epoch 18/50
# 50000/50000 [==============================] - 15s 304us/sample - loss: 0.9269 - accuracy: 0.6851 - val_loss: 0.8775 - val_accuracy: 0.7070
# Epoch 19/50
# 50000/50000 [==============================] - 15s 306us/sample - loss: 0.9130 - accuracy: 0.6882 - val_loss: 0.8895 - val_accuracy: 0.7073
# Epoch 20/50
# 50000/50000 [==============================] - 17s 337us/sample - loss: 0.9227 - accuracy: 0.6842 - val_loss: 0.8810 - val_accuracy: 0.7076
# Epoch 21/50
# 50000/50000 [==============================] - 16s 326us/sample - loss: 0.9137 - accuracy: 0.6882 - val_loss: 0.8832 - val_accuracy: 0.7079
# Epoch 22/50
# 50000/50000 [==============================] - 15s 306us/sample - loss: 0.9061 - accuracy: 0.6898 - val_loss: 0.8870 - val_accuracy: 0.7050
# Epoch 23/50
# 50000/50000 [==============================] - 16s 323us/sample - loss: 0.9216 - accuracy: 0.6864 - val_loss: 0.9276 - val_accuracy: 0.6896
# Epoch 24/50
# 50000/50000 [==============================] - 15s 300us/sample - loss: 0.9214 - accuracy: 0.6846 - val_loss: 0.8793 - val_accuracy: 0.7031
# Epoch 25/50
# 50000/50000 [==============================] - 15s 300us/sample - loss: 0.9235 - accuracy: 0.6869 - val_loss: 0.9061 - val_accuracy: 0.6959
# Epoch 26/50
# 50000/50000 [==============================] - 15s 302us/sample - loss: 0.9309 - accuracy: 0.6806 - val_loss: 0.8781 - val_accuracy: 0.7036
# Epoch 27/50
# 50000/50000 [==============================] - 15s 301us/sample - loss: 0.9174 - accuracy: 0.6883 - val_loss: 0.9438 - val_accuracy: 0.6824
# Epoch 28/50
# 50000/50000 [==============================] - 15s 306us/sample - loss: 0.9336 - accuracy: 0.6826 - val_loss: 0.8808 - val_accuracy: 0.7018
# Epoch 29/50
# 50000/50000 [==============================] - 16s 315us/sample - loss: 0.9302 - accuracy: 0.6834 - val_loss: 0.9675 - val_accuracy: 0.6766
# Epoch 30/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.9249 - accuracy: 0.6864 - val_loss: 0.9086 - val_accuracy: 0.6901
# Epoch 31/50
# 50000/50000 [==============================] - 16s 313us/sample - loss: 0.9270 - accuracy: 0.6850 - val_loss: 0.8680 - val_accuracy: 0.7096
# Epoch 32/50
# 50000/50000 [==============================] - 15s 307us/sample - loss: 0.9038 - accuracy: 0.6898 - val_loss: 0.8995 - val_accuracy: 0.6994
# Epoch 33/50
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.9267 - accuracy: 0.6843 - val_loss: 0.8886 - val_accuracy: 0.7072
# Epoch 34/50
# 50000/50000 [==============================] - 15s 300us/sample - loss: 0.9188 - accuracy: 0.6869 - val_loss: 0.8949 - val_accuracy: 0.7009
# Epoch 35/50
# 50000/50000 [==============================] - 15s 301us/sample - loss: 0.9119 - accuracy: 0.6885 - val_loss: 0.8694 - val_accuracy: 0.7125
# Epoch 36/50
# 50000/50000 [==============================] - 15s 301us/sample - loss: 0.9246 - accuracy: 0.6854 - val_loss: 0.9161 - val_accuracy: 0.6983
# Epoch 37/50
# 50000/50000 [==============================] - 15s 302us/sample - loss: 0.9398 - accuracy: 0.6766 - val_loss: 0.9161 - val_accuracy: 0.6974
# Epoch 38/50
# 50000/50000 [==============================] - 15s 302us/sample - loss: 0.9430 - accuracy: 0.6789 - val_loss: 0.8689 - val_accuracy: 0.7082
# Epoch 39/50
# 50000/50000 [==============================] - 15s 301us/sample - loss: 0.9260 - accuracy: 0.6854 - val_loss: 0.8676 - val_accuracy: 0.7139
# Epoch 40/50
# 50000/50000 [==============================] - 15s 306us/sample - loss: 0.9218 - accuracy: 0.6859 - val_loss: 0.8752 - val_accuracy: 0.7100
# Epoch 41/50
# 50000/50000 [==============================] - 15s 305us/sample - loss: 0.9245 - accuracy: 0.6853 - val_loss: 0.8755 - val_accuracy: 0.7030
# Epoch 42/50
# 50000/50000 [==============================] - 16s 314us/sample - loss: 0.9356 - accuracy: 0.6821 - val_loss: 0.9092 - val_accuracy: 0.7006
# Epoch 43/50
# 50000/50000 [==============================] - 15s 301us/sample - loss: 0.9393 - accuracy: 0.6815 - val_loss: 0.8557 - val_accuracy: 0.7125
# Epoch 44/50
# 50000/50000 [==============================] - 15s 304us/sample - loss: 0.9456 - accuracy: 0.6785 - val_loss: 0.8368 - val_accuracy: 0.7161
# Epoch 45/50
# 50000/50000 [==============================] - 16s 318us/sample - loss: 0.9481 - accuracy: 0.6761 - val_loss: 0.8708 - val_accuracy: 0.7072
# Epoch 46/50
# 50000/50000 [==============================] - 15s 308us/sample - loss: 0.9398 - accuracy: 0.6811 - val_loss: 0.8970 - val_accuracy: 0.6997
# Epoch 47/50
# 50000/50000 [==============================] - 16s 314us/sample - loss: 0.9417 - accuracy: 0.6784 - val_loss: 0.8926 - val_accuracy: 0.6992
# Epoch 48/50
# 50000/50000 [==============================] - 15s 307us/sample - loss: 0.9415 - accuracy: 0.6793 - val_loss: 0.9265 - val_accuracy: 0.6903
# Epoch 49/50
# 20800/50000 [===========>..................] - ETA: 8s - loss: 0.9355 - accuracy: 0.6802

# %% [markdown]
# ### Model 1, softmax

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='softmax', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='softmax'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='softmax'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='softmax'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])

trainModel(model, 20)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 22s 449us/sample - loss: 2.3028 - accuracy: 0.0985 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/20
# 50000/50000 [==============================] - 21s 428us/sample - loss: 2.3030 - accuracy: 0.0963 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/20
# 50000/50000 [==============================] - 21s 430us/sample - loss: 2.3029 - accuracy: 0.0982 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 4/20
# 50000/50000 [==============================] - 22s 434us/sample - loss: 2.2992 - accuracy: 0.1035 - val_loss: 2.1953 - val_accuracy: 0.1830
# Epoch 5/20
# 50000/50000 [==============================] - 22s 432us/sample - loss: 2.0862 - accuracy: 0.2306 - val_loss: 1.9615 - val_accuracy: 0.2958
# Epoch 6/20
# 50000/50000 [==============================] - 22s 430us/sample - loss: 1.9734 - accuracy: 0.2705 - val_loss: 1.8586 - val_accuracy: 0.3386
# Epoch 7/20
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8955 - accuracy: 0.2972 - val_loss: 1.7759 - val_accuracy: 0.3682
# Epoch 8/20
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.8238 - accuracy: 0.3281 - val_loss: 1.6872 - val_accuracy: 0.4121
# Epoch 9/20
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.7567 - accuracy: 0.3538 - val_loss: 1.6249 - val_accuracy: 0.4273
# Epoch 10/20
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7078 - accuracy: 0.3781 - val_loss: 1.5461 - val_accuracy: 0.4601
# Epoch 11/20
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.6620 - accuracy: 0.3989 - val_loss: 1.4906 - val_accuracy: 0.4779
# Epoch 12/20
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.6230 - accuracy: 0.4137 - val_loss: 1.4506 - val_accuracy: 0.4966
# Epoch 13/20
# 50000/50000 [==============================] - 22s 434us/sample - loss: 1.5847 - accuracy: 0.4307 - val_loss: 1.4158 - val_accuracy: 0.5088
# Epoch 14/20
# 50000/50000 [==============================] - 21s 430us/sample - loss: 1.5532 - accuracy: 0.4434 - val_loss: 1.3873 - val_accuracy: 0.5194
# Epoch 15/20
# 50000/50000 [==============================] - 22s 434us/sample - loss: 1.5250 - accuracy: 0.4564 - val_loss: 1.3412 - val_accuracy: 0.5344
# Epoch 16/20
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4883 - accuracy: 0.4759 - val_loss: 1.3102 - val_accuracy: 0.5460
# Epoch 17/20
# 50000/50000 [==============================] - 22s 439us/sample - loss: 1.4639 - accuracy: 0.4861 - val_loss: 1.2751 - val_accuracy: 0.5598
# Epoch 18/20
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4362 - accuracy: 0.4928 - val_loss: 1.2406 - val_accuracy: 0.5706
# Epoch 19/20
# 50000/50000 [==============================] - 22s 430us/sample - loss: 1.4101 - accuracy: 0.5040 - val_loss: 1.2238 - val_accuracy: 0.5816
# Epoch 20/20
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3786 - accuracy: 0.5203 - val_loss: 1.1963 - val_accuracy: 0.5855
# 10000/10000 - 1s - loss: 1.1963 - accuracy: 0.5855
# 0.5855

# %% [markdown]
# ### Adamax

# %%
def trainModelAdamax(model, epochCount):
    global history
    
    model.summary()
    
    #model.build()
    
    model.compile(optimizer='adamax',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    
    history = model.fit(train_images, train_labels, epochs=epochCount, 
                    validation_data=(test_images, test_labels))
    
    showAccuracy()
    showLoss()
    evaluateModel(model)
    
    
    
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='relu', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])
    
trainModelAdamax(model, 20)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 16s 327us/sample - loss: 1.5766 - accuracy: 0.4208 - val_loss: 1.2203 - val_accuracy: 0.5612
# Epoch 2/20
# 50000/50000 [==============================] - 17s 350us/sample - loss: 1.1710 - accuracy: 0.5834 - val_loss: 1.0066 - val_accuracy: 0.6448
# Epoch 3/20
# 50000/50000 [==============================] - 60s 1ms/sample - loss: 0.9941 - accuracy: 0.6484 - val_loss: 0.9237 - val_accuracy: 0.6817
# Epoch 4/20
# 50000/50000 [==============================] - 16s 313us/sample - loss: 0.8796 - accuracy: 0.6884 - val_loss: 0.8498 - val_accuracy: 0.7073
# Epoch 5/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.8013 - accuracy: 0.7196 - val_loss: 0.7677 - val_accuracy: 0.7360
# Epoch 6/20
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.7218 - accuracy: 0.7484 - val_loss: 0.7394 - val_accuracy: 0.7464
# Epoch 7/20
# 50000/50000 [==============================] - 16s 321us/sample - loss: 0.6739 - accuracy: 0.7628 - val_loss: 0.7101 - val_accuracy: 0.7560
# Epoch 8/20
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.6257 - accuracy: 0.7805 - val_loss: 0.7417 - val_accuracy: 0.7412
# Epoch 9/20
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.5857 - accuracy: 0.7957 - val_loss: 0.6648 - val_accuracy: 0.7693
# Epoch 10/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.5465 - accuracy: 0.8078 - val_loss: 0.6545 - val_accuracy: 0.7704
# Epoch 11/20
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.5133 - accuracy: 0.8191 - val_loss: 0.6599 - val_accuracy: 0.7700
# Epoch 12/20
# 50000/50000 [==============================] - 17s 335us/sample - loss: 0.4830 - accuracy: 0.8310 - val_loss: 0.6703 - val_accuracy: 0.7756
# Epoch 13/20
# 50000/50000 [==============================] - 16s 314us/sample - loss: 0.4551 - accuracy: 0.8397 - val_loss: 0.6583 - val_accuracy: 0.7753
# Epoch 14/20
# 50000/50000 [==============================] - 16s 319us/sample - loss: 0.4305 - accuracy: 0.8495 - val_loss: 0.6360 - val_accuracy: 0.7848
# Epoch 15/20
# 50000/50000 [==============================] - 16s 327us/sample - loss: 0.4091 - accuracy: 0.8558 - val_loss: 0.6392 - val_accuracy: 0.7812
# Epoch 16/20
# 50000/50000 [==============================] - 18s 366us/sample - loss: 0.3826 - accuracy: 0.8651 - val_loss: 0.6601 - val_accuracy: 0.7784
# Epoch 17/20
# 50000/50000 [==============================] - 16s 321us/sample - loss: 0.3640 - accuracy: 0.8728 - val_loss: 0.6392 - val_accuracy: 0.7878
# Epoch 18/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3487 - accuracy: 0.8746 - val_loss: 0.6386 - val_accuracy: 0.7882
# Epoch 19/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3309 - accuracy: 0.8813 - val_loss: 0.6569 - val_accuracy: 0.7857
# Epoch 20/20
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.3106 - accuracy: 0.8887 - val_loss: 0.6454 - val_accuracy: 0.7924
# 10000/10000 - 1s - loss: 0.6454 - accuracy: 0.7924
# 0.7924

# %% [markdown]
# ### Adadelta

# %%
def trainModelAdadelta(model, epochCount):
    global history
    
    model.summary()
    
    #model.build()
    
    model.compile(optimizer='adadelta',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    
    history = model.fit(train_images, train_labels, epochs=epochCount, 
                    validation_data=(test_images, test_labels))
    
    showAccuracy()
    showLoss()
    evaluateModel(model)
    
    
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='relu', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])

trainModelAdadelta(model, 20)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 18s 361us/sample - loss: 2.3025 - accuracy: 0.1073 - val_loss: 2.2917 - val_accuracy: 0.1112
# Epoch 2/20
# 50000/50000 [==============================] - 17s 333us/sample - loss: 2.2929 - accuracy: 0.1205 - val_loss: 2.2830 - val_accuracy: 0.1275
# Epoch 3/20
# 50000/50000 [==============================] - 16s 321us/sample - loss: 2.2833 - accuracy: 0.1340 - val_loss: 2.2722 - val_accuracy: 0.1776
# Epoch 4/20
# 50000/50000 [==============================] - 16s 328us/sample - loss: 2.2718 - accuracy: 0.1462 - val_loss: 2.2569 - val_accuracy: 0.2068
# Epoch 5/20
# 50000/50000 [==============================] - 18s 357us/sample - loss: 2.2539 - accuracy: 0.1681 - val_loss: 2.2343 - val_accuracy: 0.2254
# Epoch 6/20
# 50000/50000 [==============================] - 20s 390us/sample - loss: 2.2316 - accuracy: 0.1827 - val_loss: 2.2018 - val_accuracy: 0.2442
# Epoch 7/20
# 50000/50000 [==============================] - 17s 340us/sample - loss: 2.1965 - accuracy: 0.2041 - val_loss: 2.1584 - val_accuracy: 0.2637
# Epoch 8/20
# 50000/50000 [==============================] - 16s 327us/sample - loss: 2.1536 - accuracy: 0.2195 - val_loss: 2.1086 - val_accuracy: 0.2751
# Epoch 9/20
# 50000/50000 [==============================] - 17s 334us/sample - loss: 2.1124 - accuracy: 0.2297 - val_loss: 2.0632 - val_accuracy: 0.2859
# Epoch 10/20
# 50000/50000 [==============================] - 17s 331us/sample - loss: 2.0752 - accuracy: 0.2390 - val_loss: 2.0275 - val_accuracy: 0.2856
# Epoch 11/20
# 50000/50000 [==============================] - 17s 332us/sample - loss: 2.0483 - accuracy: 0.2481 - val_loss: 2.0025 - val_accuracy: 0.2915
# Epoch 12/20
# 50000/50000 [==============================] - 17s 333us/sample - loss: 2.0255 - accuracy: 0.2545 - val_loss: 1.9829 - val_accuracy: 0.2952
# Epoch 13/20
# 50000/50000 [==============================] - 16s 326us/sample - loss: 2.0087 - accuracy: 0.2626 - val_loss: 1.9656 - val_accuracy: 0.3057
# Epoch 14/20
# 50000/50000 [==============================] - 16s 329us/sample - loss: 1.9914 - accuracy: 0.2717 - val_loss: 1.9489 - val_accuracy: 0.3134
# Epoch 15/20
# 50000/50000 [==============================] - 16s 316us/sample - loss: 1.9774 - accuracy: 0.2788 - val_loss: 1.9331 - val_accuracy: 0.3178
# Epoch 16/20
# 50000/50000 [==============================] - 17s 336us/sample - loss: 1.9626 - accuracy: 0.2823 - val_loss: 1.9171 - val_accuracy: 0.3244
# Epoch 17/20
# 50000/50000 [==============================] - 16s 319us/sample - loss: 1.9463 - accuracy: 0.2898 - val_loss: 1.8988 - val_accuracy: 0.3298
# Epoch 18/20
# 50000/50000 [==============================] - 16s 321us/sample - loss: 1.9259 - accuracy: 0.3015 - val_loss: 1.8791 - val_accuracy: 0.3376
# Epoch 19/20
# 50000/50000 [==============================] - 16s 325us/sample - loss: 1.9089 - accuracy: 0.3071 - val_loss: 1.8608 - val_accuracy: 0.3449
# Epoch 20/20
# 50000/50000 [==============================] - 17s 344us/sample - loss: 1.8932 - accuracy: 0.3156 - val_loss: 1.8456 - val_accuracy: 0.3492
# 10000/10000 - 1s - loss: 1.8456 - accuracy: 0.3492
# 0.3492

# %% [markdown]
# ## Loss Functions

# %% [markdown]
# ### Kullback Leibler Divergence Loss

# %%
def trainModelNonSparse(model, epochCount):
    global history
    
    model.summary()
    
    #model.build()
    
    opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
    
    model.compile(optimizer=opt,
              loss='kullback_leibler_divergence',
              metrics=['accuracy'])
    
    history = model.fit(train_images, train_labels, epochs=epochCount, 
                    validation_data=(test_images, test_labels))
    
    showAccuracy()
    showLoss()
    evaluateModel(model)
    
    
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='relu', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])

trainModelNonSparse(model, 20)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_66 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_44 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_45 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 17s 334us/sample - loss: 14.2583 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 50000/50000 [==============================] - 15s 308us/sample - loss: 14.2017 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 14.2197 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 50000/50000 [==============================] - 15s 308us/sample - loss: 14.2091 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 50000/50000 [==============================] - 15s 308us/sample - loss: 14.2155 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 50000/50000 [==============================] - 15s 308us/sample - loss: 14.2297 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 50000/50000 [==============================] - 17s 334us/sample - loss: 14.2249 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 50000/50000 [==============================] - 16s 316us/sample - loss: 14.2152 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 50000/50000 [==============================] - 15s 306us/sample - loss: 14.2174 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 14.2287 - accuracy: 0.0000e+00 - val_loss: 14.5063 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 16096/50000 [========>.....................] - ETA: 9s - loss: 14.2455 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-def69f3363e6> in <module>
#      35 ])
#      36
# ---> 37 trainModelNonSparse(model, 20)
#
# <ipython-input-41-def69f3363e6> in trainModelNonSparse(model, epochCount)
#      13
#      14     history = model.fit(train_images, train_labels, epochs=epochCount,
# ---> 15                     validation_data=(test_images, test_labels))
#      16
#      17     showAccuracy()
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in _non_none_constant_value(v)
#     128
#     129 def _non_none_constant_value(v):
# --> 130   constant_value = tensor_util.constant_value(v)
#     131   return constant_value if constant_value is not None else v
#     132
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\framework\tensor_util.py in constant_value(tensor, partial)
#     820   """
#     821   if isinstance(tensor, ops.EagerTensor):
# --> 822     return tensor.numpy()
#     823   if not is_tensor(tensor):
#     824     return tensor
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\framework\ops.py in numpy(self)
#     940     """
#     941     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 942     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     943     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     944
#
# ~\Anaconda3\envs\AIenv1\lib\site-packages\tensorflow_core\python\framework\ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Adamax + Tanh

# %%
def trainModelAdamaxTanH(model, epochCount):
    global history
    
    model.summary()
    
    #model.build()
    
    model.compile(optimizer='adamax',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    
    history = model.fit(train_images, train_labels, epochs=epochCount, 
                    validation_data=(test_images, test_labels))
    
    showAccuracy()
    showLoss()
    evaluateModel(model)
    
    
    
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", activation='tanh', input_shape=(32,32,3)),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Conv2D(64, (5, 5), padding="same", activation='tanh'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Conv2D(128, (5, 5), padding="same", activation='tanh'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),
    keras.layers.Dropout(0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='tanh'),
    keras.layers.Dropout(0.4),                     
    keras.layers.Dense(10)
])
    
trainModelAdamax(model, 20)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_69 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,367,050
# Trainable params: 2,367,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 17s 331us/sample - loss: 1.4351 - accuracy: 0.4883 - val_loss: 1.1772 - val_accuracy: 0.5876
# Epoch 2/20
# 50000/50000 [==============================] - 16s 316us/sample - loss: 1.1345 - accuracy: 0.6028 - val_loss: 1.0592 - val_accuracy: 0.6274
# Epoch 3/20
# 50000/50000 [==============================] - 16s 315us/sample - loss: 1.0238 - accuracy: 0.6447 - val_loss: 0.9789 - val_accuracy: 0.6694
# Epoch 4/20
# 50000/50000 [==============================] - 16s 316us/sample - loss: 0.9516 - accuracy: 0.6690 - val_loss: 0.9370 - val_accuracy: 0.6759
# Epoch 5/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.8927 - accuracy: 0.6912 - val_loss: 0.8943 - val_accuracy: 0.6984
# Epoch 6/20
# 50000/50000 [==============================] - 15s 308us/sample - loss: 0.8379 - accuracy: 0.7067 - val_loss: 0.8715 - val_accuracy: 0.7039
# Epoch 7/20
# 50000/50000 [==============================] - 16s 314us/sample - loss: 0.7930 - accuracy: 0.7267 - val_loss: 0.8719 - val_accuracy: 0.7049
# Epoch 8/20
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.7511 - accuracy: 0.7388 - val_loss: 0.8612 - val_accuracy: 0.7119
# Epoch 9/20
# 50000/50000 [==============================] - 16s 313us/sample - loss: 0.7189 - accuracy: 0.7476 - val_loss: 0.8689 - val_accuracy: 0.7126
# Epoch 10/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.6846 - accuracy: 0.7607 - val_loss: 0.9069 - val_accuracy: 0.7016
# Epoch 11/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.6493 - accuracy: 0.7713 - val_loss: 0.8651 - val_accuracy: 0.7193
# Epoch 12/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.6267 - accuracy: 0.7803 - val_loss: 0.8604 - val_accuracy: 0.7182
# Epoch 13/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.5936 - accuracy: 0.7917 - val_loss: 0.8931 - val_accuracy: 0.7083
# Epoch 14/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.5680 - accuracy: 0.8010 - val_loss: 0.8709 - val_accuracy: 0.7231
# Epoch 15/20
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.5378 - accuracy: 0.8101 - val_loss: 0.8344 - val_accuracy: 0.7349
# Epoch 16/20
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.5179 - accuracy: 0.8179 - val_loss: 0.8433 - val_accuracy: 0.7381
# Epoch 17/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.4945 - accuracy: 0.8260 - val_loss: 0.8703 - val_accuracy: 0.7259
# Epoch 18/20
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.4737 - accuracy: 0.8300 - val_loss: 0.8661 - val_accuracy: 0.7314
# Epoch 19/20
# 50000/50000 [==============================] - 16s 318us/sample - loss: 0.4487 - accuracy: 0.8407 - val_loss: 0.8857 - val_accuracy: 0.7333
# Epoch 20/20
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.4335 - accuracy: 0.8466 - val_loss: 0.8473 - val_accuracy: 0.7427
# 10000/10000 - 1s - loss: 0.8473 - accuracy: 0.7427
# 0.7427
